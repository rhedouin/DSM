# %%
# Check data
import os
import pandas as pd
import rasterio
import matplotlib.pyplot as plt

os.chdir("/workspaces/DSM/data/aligned/caen")

for file in os.listdir():
    if file.endswith(".tif"):
        print(file)
        with rasterio.open(file) as src:
            target = src.read(1).astype("float32")
            plt.imshow(target, cmap="terrain")
            plt.colorbar()
            plt.show()

        print("Data shape:", target.shape)
# Out:
# tcd.tif
# Data shape: (360, 360)
# imd.tif
# Data shape: (360, 360)
# dtm_lidar.tif
# Data shape: (360, 360)
# sentinel2.tif
# Data shape: (360, 360)
# copdem30.tif
# Data shape: (360, 360)
# slope.tif
# Data shape: (360, 360)
